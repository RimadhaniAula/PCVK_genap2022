# %% [markdown]
# <a href="https://colab.research.google.com/github/RimadhaniAula/PCVK_genap2022/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Divisi Komputer/dobby.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Divisi Komputer/dobby.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan file image
#cv.imwrite('/content/drive/MyDrive/Divisi Komputer/dobby.jpg', img5)

#tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(5,5)) # ubah sesuai kebutuhan 
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(340,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100, 300],[200, 200],
                     [400, 300],[200, 400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukan tiap titik dibuat 3 channel
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **TASK**

# %% [markdown]
# 1 Show images in Red-Green and Green-Blue channels only!

# %%
img6 = img

# split each channel of the image
(B, G, R) = cv.split(img6)
# represent zero color by the shape of the image
zeros = np.zeros(img6.shape[:2], dtype="uint8")

# show Red + Green color channel only
rg = cv.merge([R,G,zeros])
plt.imshow(rg)

# %%
# show Green + Blue color channel only
gb = cv.merge([zeros,G,B])
plt.imshow(gb)

# %% [markdown]
# 2 Show image row 10-100, column 10-100!

# %%
img7 = img6[9:99, 9:99]
plt.imshow(img7)

# %% [markdown]
# 3 Show image rows 5-30, all columns, channel Green only!

# %%
img8 = img6[4:29,:,1] # 1 is green channel, 0 -> Blue, 1 -> Green, 2 -> Red

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.imshow(img8)

# %% [markdown]
# 4 Create 5 boxes of different sizes and colors in one image. it is recommended to use random numbers!

# %%
from random import randint

# make 2d geometry starting with black image
black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)

# loop 5 iterations to draw rectangle with random width & height points, random colors and thickness
for _ in range(0, 5):
  cv.rectangle(black_img, pt1=(randint(0, 512),randint(0, 512)), pt2=(randint(0, 512),randint(0, 512)), color=(randint(0, 255),randint(0, 255),randint(0, 255)), thickness=randint(5,15))

plt.imshow(black_img)

# %% [markdown]
# 5 Show the image upside down! Based on practicum sections 3 and 4, do the following tasks:

# %%
img7 = cv.flip(img, 0)
plt.imshow(img7)

# %% [markdown]
# 6 Make rectangles and circles on the face of your photo image when you are active (not a passport photo).

# %%
img8 = img_gray

# create circle with self-estimated value for the center of cat's face
cv.circle(img8, center=(750, 375), radius=800, color=(255,0,0), thickness=8)
cv.rectangle(img8, pt1=(1250, 875), pt2=(500,0), color=(255,0,0), thickness=10)
plt.imshow(img8, cmap='gray')

# %% [markdown]
# 7 Create a rectangle in the lower left corner of channel B in the RGB color space from the kitten / lena / mandrill / male / female / couple / sailboat / peppers image !

# %%
img9 = img

# split each channel of the image
(B, G, R) = cv.split(img9)

# represent zero color by the shape of the image
zeros = np.zeros(img9.shape[:2], dtype="uint8")

# create rectangle pt1=[x, y], pt2=[x,y]
cv.rectangle(B, pt1=(1000,2500), pt2=(0,1500), color=(255,255,255), thickness=15)

b = cv.merge([zeros,zeros,B])
plt.imshow(b)
